# %% [markdown]
# # Lien vers la base :
# https://www.kaggle.com/datasets/hasyimabdillah/workoutfitness-video

# %%
import cv2
import mediapipe as mp
import os
import subprocess

# Initialize MediaPipe body segmentation
mp_selfie_segmentation = mp.solutions.selfie_segmentation.SelfieSegmentation(model_selection=1)

def process_segmentation(input_path, output_path):
    cap = cv2.VideoCapture(input_path)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH) / 2)  # Reduce the size by half
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT) / 2)  # Reduce the size by half
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Convert the BGR image to RGB
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the image to get the segmentation mask
        result = mp_selfie_segmentation.process(rgb_frame)

        # Extract segmentation mask
        mask = result.segmentation_mask
        condition = mask > 0.1

        # Apply the mask to the frame
        segmented_frame = cv2.bitwise_and(frame, frame, mask=condition.astype('uint8') * 255)

        # Resize the frame
        resized_frame = cv2.resize(segmented_frame, (width, height))

        # Write the frame to the output video
        out.write(resized_frame)

    cap.release()
    out.release()

def process_edges(input_path, output_path):
    cap = cv2.VideoCapture(input_path)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH) / 2)  # Reduce the size by half
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT) / 2)  # Reduce the size by half
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Resize the frame
        resized_frame = cv2.resize(frame, (width, height))

        # Convert to grayscale
        gray_frame = cv2.cvtColor(resized_frame, cv2.COLOR_BGR2GRAY)

        # Apply Canny edge detection
        edges = cv2.Canny(gray_frame, 100, 200)

        # Convert edges to BGR
        edges_bgr = cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)

        # Write the frame to the output video
        out.write(edges_bgr)

    cap.release()
    out.release()

def convert_to_h264(input_path, output_path):
    command = ['ffmpeg', '-i', input_path, '-vcodec', 'libx264', output_path]
    print(f"Running command: {' '.join(command)}")
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    if result.returncode != 0:
        print(f"Error converting to H264: {result.stderr.decode()}")
    else:
        print(f"Successfully converted to H264: {output_path}")

def process_videos_in_folder(input_folder, output_folder):
    for root, dirs, files in os.walk(input_folder):
        for file in files:
            if file.endswith(".mov") or file.endswith(".mp4"):
                input_path = os.path.join(root, file)
                relative_path = os.path.relpath(root, input_folder)
                output_subfolder = os.path.join(output_folder, relative_path)

                if not os.path.exists(output_subfolder):
                    os.makedirs(output_subfolder)

                output_segmentation_path = os.path.join(output_subfolder, f"{os.path.splitext(file)[0]}_segmentation.mp4")
                output_segmentation_h264_path = os.path.join(output_subfolder, f"{os.path.splitext(file)[0]}_segmentation_h264.mp4")
                output_edges_path = os.path.join(output_subfolder, f"{os.path.splitext(file)[0]}_edges.mp4")
                output_edges_h264_path = os.path.join(output_subfolder, f"{os.path.splitext(file)[0]}_edges_h264.mp4")

                print(f"Processing {input_path}...")

                # Process segmentation
                process_segmentation(input_path, output_segmentation_path)
                # Convert segmentation to H264
                convert_to_h264(output_segmentation_path, output_segmentation_h264_path)
                # Process edges
                process_edges(output_segmentation_h264_path, output_edges_path)
                # Convert edges to H264
                convert_to_h264(output_edges_path, output_edges_h264_path)

                # Remove other files
                os.remove(output_segmentation_path)
                os.remove(output_segmentation_h264_path)
                os.remove(output_edges_path)

                print(f"Processed and saved {file} in {output_subfolder}")

if __name__ == "__main__":
    input_folder = "test"  
    output_folder = "FINAL" 

    process_videos_in_folder(input_folder, output_folder)
# Out:
# Processing test\barbell biceps curl\barbell biceps curl_1.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_1_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_1_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_1_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_1_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_1_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_1_edges_h264.mp4
# Processed and saved barbell biceps curl_1.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_10.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_10_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_10_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_10_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_10_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_10_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_10_edges_h264.mp4
# Processed and saved barbell biceps curl_10.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_11.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_11_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_11_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_11_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_11_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_11_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_11_edges_h264.mp4
# Processed and saved barbell biceps curl_11.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_12.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_12_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_12_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_12_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_12_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_12_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_12_edges_h264.mp4
# Processed and saved barbell biceps curl_12.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_13.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_13_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_13_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_13_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_13_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_13_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_13_edges_h264.mp4
# Processed and saved barbell biceps curl_13.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_14.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_14_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_14_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_14_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_14_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_14_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_14_edges_h264.mp4
# Processed and saved barbell biceps curl_14.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_15.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_15_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_15_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_15_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_15_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_15_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_15_edges_h264.mp4
# Processed and saved barbell biceps curl_15.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_16.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_16_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_16_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_16_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_16_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_16_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_16_edges_h264.mp4
# Processed and saved barbell biceps curl_16.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_17.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_17_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_17_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_17_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_17_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_17_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_17_edges_h264.mp4
# Processed and saved barbell biceps curl_17.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_18.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_18_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_18_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_18_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_18_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_18_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_18_edges_h264.mp4
# Processed and saved barbell biceps curl_18.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_19.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_19_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_19_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_19_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_19_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_19_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_19_edges_h264.mp4
# Processed and saved barbell biceps curl_19.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_2.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_2_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_2_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_2_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_2_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_2_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_2_edges_h264.mp4
# Processed and saved barbell biceps curl_2.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_20.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_20_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_20_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_20_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_20_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_20_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_20_edges_h264.mp4
# Processed and saved barbell biceps curl_20.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_21.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_21_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_21_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_21_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_21_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_21_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_21_edges_h264.mp4
# Processed and saved barbell biceps curl_21.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_22.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_22_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_22_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_22_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_22_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_22_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_22_edges_h264.mp4
# Processed and saved barbell biceps curl_22.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_23.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_23_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_23_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_23_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_23_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_23_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_23_edges_h264.mp4
# Processed and saved barbell biceps curl_23.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_24.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_24_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_24_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_24_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_24_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_24_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_24_edges_h264.mp4
# Processed and saved barbell biceps curl_24.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_25.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_25_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_25_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_25_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_25_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_25_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_25_edges_h264.mp4
# Processed and saved barbell biceps curl_25.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_26.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_26_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_26_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_26_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_26_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_26_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_26_edges_h264.mp4
# Processed and saved barbell biceps curl_26.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_27.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_27_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_27_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_27_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_27_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_27_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_27_edges_h264.mp4
# Processed and saved barbell biceps curl_27.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_28.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_28_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_28_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_28_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_28_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_28_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_28_edges_h264.mp4
# Processed and saved barbell biceps curl_28.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_29.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_29_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_29_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_29_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_29_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_29_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_29_edges_h264.mp4
# Processed and saved barbell biceps curl_29.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_3.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_3_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_3_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_3_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_3_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_3_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_3_edges_h264.mp4
# Processed and saved barbell biceps curl_3.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_30.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_30_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_30_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_30_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_30_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_30_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_30_edges_h264.mp4
# Processed and saved barbell biceps curl_30.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_31.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_31_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_31_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_31_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_31_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_31_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_31_edges_h264.mp4
# Processed and saved barbell biceps curl_31.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_32.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_32_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_32_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_32_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_32_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_32_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_32_edges_h264.mp4
# Processed and saved barbell biceps curl_32.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_33.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_33_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_33_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_33_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_33_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_33_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_33_edges_h264.mp4
# Processed and saved barbell biceps curl_33.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_34.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_34_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_34_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_34_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_34_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_34_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_34_edges_h264.mp4
# Processed and saved barbell biceps curl_34.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_35.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_35_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_35_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_35_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_35_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_35_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_35_edges_h264.mp4
# Processed and saved barbell biceps curl_35.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_36.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_36_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_36_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_36_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_36_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_36_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_36_edges_h264.mp4
# Processed and saved barbell biceps curl_36.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_37.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_37_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_37_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_37_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_37_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_37_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_37_edges_h264.mp4
# Processed and saved barbell biceps curl_37.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_38.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_38_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_38_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_38_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_38_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_38_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_38_edges_h264.mp4
# Processed and saved barbell biceps curl_38.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_39.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_39_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_39_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_39_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_39_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_39_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_39_edges_h264.mp4
# Processed and saved barbell biceps curl_39.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_4.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_4_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_4_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_4_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_4_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_4_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_4_edges_h264.mp4
# Processed and saved barbell biceps curl_4.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_40.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_40_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_40_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_40_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_40_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_40_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_40_edges_h264.mp4
# Processed and saved barbell biceps curl_40.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_41.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_41_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_41_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_41_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_41_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_41_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_41_edges_h264.mp4
# Processed and saved barbell biceps curl_41.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_42.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_42_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_42_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_42_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_42_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_42_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_42_edges_h264.mp4
# Processed and saved barbell biceps curl_42.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_43.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_43_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_43_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_43_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_43_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_43_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_43_edges_h264.mp4
# Processed and saved barbell biceps curl_43.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_44.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_44_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_44_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_44_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_44_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_44_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_44_edges_h264.mp4
# Processed and saved barbell biceps curl_44.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_45.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_45_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_45_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_45_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_45_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_45_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_45_edges_h264.mp4
# Processed and saved barbell biceps curl_45.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_46.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_46_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_46_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_46_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_46_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_46_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_46_edges_h264.mp4
# Processed and saved barbell biceps curl_46.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_47.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_47_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_47_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_47_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_47_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_47_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_47_edges_h264.mp4
# Processed and saved barbell biceps curl_47.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_48.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_48_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_48_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_48_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_48_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_48_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_48_edges_h264.mp4
# Processed and saved barbell biceps curl_48.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_49.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_49_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_49_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_49_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_49_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_49_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_49_edges_h264.mp4
# Processed and saved barbell biceps curl_49.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_5.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_5_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_5_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_5_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_5_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_5_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_5_edges_h264.mp4
# Processed and saved barbell biceps curl_5.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_50.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_50_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_50_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_50_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_50_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_50_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_50_edges_h264.mp4
# Processed and saved barbell biceps curl_50.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_51.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_51_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_51_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_51_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_51_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_51_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_51_edges_h264.mp4
# Processed and saved barbell biceps curl_51.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_52.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_52_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_52_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_52_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_52_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_52_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_52_edges_h264.mp4
# Processed and saved barbell biceps curl_52.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_53.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_53_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_53_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_53_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_53_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_53_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_53_edges_h264.mp4
# Processed and saved barbell biceps curl_53.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_54.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_54_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_54_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_54_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_54_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_54_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_54_edges_h264.mp4
# Processed and saved barbell biceps curl_54.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_55.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_55_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_55_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_55_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_55_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_55_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_55_edges_h264.mp4
# Processed and saved barbell biceps curl_55.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_56.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_56_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_56_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_56_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_56_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_56_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_56_edges_h264.mp4
# Processed and saved barbell biceps curl_56.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_57.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_57_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_57_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_57_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_57_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_57_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_57_edges_h264.mp4
# Processed and saved barbell biceps curl_57.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_58.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_58_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_58_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_58_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_58_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_58_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_58_edges_h264.mp4
# Processed and saved barbell biceps curl_58.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_59.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_59_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_59_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_59_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_59_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_59_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_59_edges_h264.mp4
# Processed and saved barbell biceps curl_59.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_6.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_6_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_6_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_6_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_6_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_6_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_6_edges_h264.mp4
# Processed and saved barbell biceps curl_6.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_60.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_60_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_60_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_60_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_60_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_60_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_60_edges_h264.mp4
# Processed and saved barbell biceps curl_60.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_61.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_61_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_61_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_61_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_61_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_61_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_61_edges_h264.mp4
# Processed and saved barbell biceps curl_61.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_62.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_62_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_62_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_62_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_62_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_62_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_62_edges_h264.mp4
# Processed and saved barbell biceps curl_62.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_7.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_7_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_7_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_7_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_7_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_7_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_7_edges_h264.mp4
# Processed and saved barbell biceps curl_7.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_8.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_8_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_8_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_8_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_8_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_8_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_8_edges_h264.mp4
# Processed and saved barbell biceps curl_8.mp4 in FINAL\barbell biceps curl
# Processing test\barbell biceps curl\barbell biceps curl_9.mp4...
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_9_segmentation.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_9_segmentation_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_9_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\barbell biceps curl\barbell biceps curl_9_edges.mp4 -vcodec libx264 FINAL\barbell biceps curl\barbell biceps curl_9_edges_h264.mp4
# Successfully converted to H264: FINAL\barbell biceps curl\barbell biceps curl_9_edges_h264.mp4
# Processed and saved barbell biceps curl_9.mp4 in FINAL\barbell biceps curl
# Processing test\bench press\bench press_1.mp4...
# Running command: ffmpeg -i FINAL\bench press\bench press_1_segmentation.mp4 -vcodec libx264 FINAL\bench press\bench press_1_segmentation_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_1_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\bench press\bench press_1_edges.mp4 -vcodec libx264 FINAL\bench press\bench press_1_edges_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_1_edges_h264.mp4
# Processed and saved bench press_1.mp4 in FINAL\bench press
# Processing test\bench press\bench press_10.mp4...
# Running command: ffmpeg -i FINAL\bench press\bench press_10_segmentation.mp4 -vcodec libx264 FINAL\bench press\bench press_10_segmentation_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_10_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\bench press\bench press_10_edges.mp4 -vcodec libx264 FINAL\bench press\bench press_10_edges_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_10_edges_h264.mp4
# Processed and saved bench press_10.mp4 in FINAL\bench press
# Processing test\bench press\bench press_11.mp4...
# Running command: ffmpeg -i FINAL\bench press\bench press_11_segmentation.mp4 -vcodec libx264 FINAL\bench press\bench press_11_segmentation_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_11_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\bench press\bench press_11_edges.mp4 -vcodec libx264 FINAL\bench press\bench press_11_edges_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_11_edges_h264.mp4
# Processed and saved bench press_11.mp4 in FINAL\bench press
# Processing test\bench press\bench press_12.mp4...
# Running command: ffmpeg -i FINAL\bench press\bench press_12_segmentation.mp4 -vcodec libx264 FINAL\bench press\bench press_12_segmentation_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_12_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\bench press\bench press_12_edges.mp4 -vcodec libx264 FINAL\bench press\bench press_12_edges_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_12_edges_h264.mp4
# Processed and saved bench press_12.mp4 in FINAL\bench press
# Processing test\bench press\bench press_13.mp4...
# Running command: ffmpeg -i FINAL\bench press\bench press_13_segmentation.mp4 -vcodec libx264 FINAL\bench press\bench press_13_segmentation_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_13_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\bench press\bench press_13_edges.mp4 -vcodec libx264 FINAL\bench press\bench press_13_edges_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_13_edges_h264.mp4
# Processed and saved bench press_13.mp4 in FINAL\bench press
# Processing test\bench press\bench press_14.mp4...
# Running command: ffmpeg -i FINAL\bench press\bench press_14_segmentation.mp4 -vcodec libx264 FINAL\bench press\bench press_14_segmentation_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_14_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\bench press\bench press_14_edges.mp4 -vcodec libx264 FINAL\bench press\bench press_14_edges_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_14_edges_h264.mp4
# Processed and saved bench press_14.mp4 in FINAL\bench press
# Processing test\bench press\bench press_15.mp4...
# Running command: ffmpeg -i FINAL\bench press\bench press_15_segmentation.mp4 -vcodec libx264 FINAL\bench press\bench press_15_segmentation_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_15_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\bench press\bench press_15_edges.mp4 -vcodec libx264 FINAL\bench press\bench press_15_edges_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_15_edges_h264.mp4
# Processed and saved bench press_15.mp4 in FINAL\bench press
# Processing test\bench press\bench press_16.mp4...
# Running command: ffmpeg -i FINAL\bench press\bench press_16_segmentation.mp4 -vcodec libx264 FINAL\bench press\bench press_16_segmentation_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_16_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\bench press\bench press_16_edges.mp4 -vcodec libx264 FINAL\bench press\bench press_16_edges_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_16_edges_h264.mp4
# Processed and saved bench press_16.mp4 in FINAL\bench press
# Processing test\bench press\bench press_17.mp4...
# Running command: ffmpeg -i FINAL\bench press\bench press_17_segmentation.mp4 -vcodec libx264 FINAL\bench press\bench press_17_segmentation_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_17_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\bench press\bench press_17_edges.mp4 -vcodec libx264 FINAL\bench press\bench press_17_edges_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_17_edges_h264.mp4
# Processed and saved bench press_17.mp4 in FINAL\bench press
# Processing test\bench press\bench press_18.mp4...
# Running command: ffmpeg -i FINAL\bench press\bench press_18_segmentation.mp4 -vcodec libx264 FINAL\bench press\bench press_18_segmentation_h264.mp4
# Successfully converted to H264: FINAL\bench press\bench press_18_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\bench press\bench press_18_edges.mp4 -vcodec libx264 FINAL\bench press\bench press_18_edges_h264.mp4
# ...
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_31_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_31_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_31_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_31_edges_h264.mp4
# Processed and saved tricep pushdown_31.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_32.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_32_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_32_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_32_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_32_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_32_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_32_edges_h264.mp4
# Processed and saved tricep pushdown_32.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_33.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_33_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_33_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_33_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_33_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_33_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_33_edges_h264.mp4
# Processed and saved tricep pushdown_33.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_34.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_34_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_34_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_34_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_34_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_34_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_34_edges_h264.mp4
# Processed and saved tricep pushdown_34.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_35.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_35_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_35_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_35_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_35_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_35_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_35_edges_h264.mp4
# Processed and saved tricep pushdown_35.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_36.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_36_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_36_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_36_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_36_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_36_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_36_edges_h264.mp4
# Processed and saved tricep pushdown_36.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_37.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_37_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_37_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_37_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_37_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_37_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_37_edges_h264.mp4
# Processed and saved tricep pushdown_37.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_38.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_38_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_38_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_38_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_38_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_38_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_38_edges_h264.mp4
# Processed and saved tricep pushdown_38.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_39.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_39_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_39_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_39_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_39_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_39_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_39_edges_h264.mp4
# Processed and saved tricep pushdown_39.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_4.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_4_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_4_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_4_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_4_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_4_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_4_edges_h264.mp4
# Processed and saved tricep pushdown_4.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_40.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_40_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_40_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_40_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_40_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_40_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_40_edges_h264.mp4
# Processed and saved tricep pushdown_40.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_41.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_41_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_41_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_41_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_41_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_41_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_41_edges_h264.mp4
# Processed and saved tricep pushdown_41.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_42.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_42_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_42_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_42_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_42_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_42_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_42_edges_h264.mp4
# Processed and saved tricep pushdown_42.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_43.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_43_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_43_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_43_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_43_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_43_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_43_edges_h264.mp4
# Processed and saved tricep pushdown_43.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_44.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_44_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_44_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_44_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_44_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_44_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_44_edges_h264.mp4
# Processed and saved tricep pushdown_44.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_45.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_45_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_45_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_45_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_45_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_45_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_45_edges_h264.mp4
# Processed and saved tricep pushdown_45.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_46.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_46_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_46_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_46_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_46_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_46_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_46_edges_h264.mp4
# Processed and saved tricep pushdown_46.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_47.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_47_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_47_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_47_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_47_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_47_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_47_edges_h264.mp4
# Processed and saved tricep pushdown_47.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_48.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_48_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_48_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_48_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_48_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_48_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_48_edges_h264.mp4
# Processed and saved tricep pushdown_48.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_49.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_49_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_49_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_49_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_49_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_49_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_49_edges_h264.mp4
# Processed and saved tricep pushdown_49.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_5.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_5_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_5_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_5_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_5_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_5_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_5_edges_h264.mp4
# Processed and saved tricep pushdown_5.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_50.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_50_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_50_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_50_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_50_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_50_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_50_edges_h264.mp4
# Processed and saved tricep pushdown_50.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_6.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_6_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_6_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_6_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_6_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_6_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_6_edges_h264.mp4
# Processed and saved tricep pushdown_6.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_7.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_7_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_7_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_7_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_7_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_7_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_7_edges_h264.mp4
# Processed and saved tricep pushdown_7.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_8.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_8_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_8_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_8_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_8_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_8_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_8_edges_h264.mp4
# Processed and saved tricep pushdown_8.mp4 in FINAL\tricep Pushdown
# Processing test\tricep Pushdown\tricep pushdown_9.mp4...
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_9_segmentation.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_9_segmentation_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_9_segmentation_h264.mp4
# Running command: ffmpeg -i FINAL\tricep Pushdown\tricep pushdown_9_edges.mp4 -vcodec libx264 FINAL\tricep Pushdown\tricep pushdown_9_edges_h264.mp4
# Successfully converted to H264: FINAL\tricep Pushdown\tricep pushdown_9_edges_h264.mp4
# Processed and saved tricep pushdown_9.mp4 in FINAL\tricep Pushdown

# %%
import os
import cv2
import numpy as np
import tensorflow as tf

class VideoDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, folder_path, img_size=(112, 112), max_frames=30, batch_size=4, shuffle=True):
        self.folder_path = folder_path
        self.img_size = img_size
        self.max_frames = max_frames
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.classes = os.listdir(folder_path)
        self.filepaths = []
        self.labels = []
        
        for cls in self.classes:
            cls_folder = os.path.join(folder_path, cls)
            videos = os.listdir(cls_folder)
            for video in videos:
                self.filepaths.append(os.path.join(cls_folder, video))
                self.labels.append(self.classes.index(cls))
        
        self.on_epoch_end()
    
    def __len__(self):
        return len(self.filepaths) // self.batch_size
    
    def __getitem__(self, index):
        batch_filepaths = self.filepaths[index*self.batch_size:(index+1)*self.batch_size]
        batch_labels = self.labels[index*self.batch_size:(index+1)*self.batch_size]
        
        X, y = self.__data_generation(batch_filepaths, batch_labels)
        return X, y
    
    def on_epoch_end(self):
        self.indexes = np.arange(len(self.filepaths))
        if self.shuffle:
            np.random.shuffle(self.indexes)
    
    def __data_generation(self, batch_filepaths, batch_labels):
        X = np.zeros((self.batch_size, self.max_frames, self.img_size[0], self.img_size[1], 3), dtype=np.float32)
        y = np.zeros((self.batch_size), dtype=int)  # Changed from np.int to int
        
        for i, (filepath, label) in enumerate(zip(batch_filepaths, batch_labels)):
            cap = cv2.VideoCapture(filepath)
            frames = []
            frame_count = 0
            
            while cap.isOpened() and frame_count < self.max_frames:
                ret, frame = cap.read()
                if not ret:
                    break
                frame = cv2.resize(frame, self.img_size)
                frames.append(frame)
                frame_count += 1
            
            cap.release()
            
            # If less frames, pad with zeros
            while len(frames) < self.max_frames:
                frames.append(np.zeros((self.img_size[0], self.img_size[1], 3), dtype=np.uint8))
            
            X[i] = np.array(frames)
            y[i] = label
        
        X = X / 255.0  # Normalize pixel values
        return X, y

# Load data using generator
data_path = 'FINAL'
img_size = (112, 112)
max_frames = 30
batch_size = 4  # Reduced batch size

train_generator = VideoDataGenerator(data_path, img_size=img_size, max_frames=max_frames, batch_size=batch_size, shuffle=True)
val_generator = VideoDataGenerator(data_path, img_size=img_size, max_frames=max_frames, batch_size=batch_size, shuffle=False)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, LSTM, TimeDistributed

def create_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    
    x = TimeDistributed(Conv2D(16, (3, 3), activation='relu'))(inputs)
    x = TimeDistributed(MaxPooling2D((2, 2)))(x)
    
    x = TimeDistributed(Conv2D(32, (3, 3), activation='relu'))(x)
    x = TimeDistributed(MaxPooling2D((2, 2)))(x)
    
    x = TimeDistributed(Flatten())(x)
    x = LSTM(64)(x)
    
    x = Dense(32, activation='relu')(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    return model

input_shape = (max_frames, img_size[0], img_size[1], 3)
num_classes = len(os.listdir(data_path))
model = create_model(input_shape, num_classes)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 30, 112, 112,   │             0 │
# │                                 │ 3)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_21             │ (None, 30, 110, 110,   │           448 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_22             │ (None, 30, 55, 55, 16) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_23             │ (None, 30, 53, 53, 32) │         4,640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_24             │ (None, 30, 26, 26, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_25             │ (None, 30, 21632)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 64)             │     5,554,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 22)             │           726 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,562,326 (21.22 MB)
#  Trainable params: 5,562,326 (21.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train model using the generator
model.fit(train_generator, epochs=10)
# Out:
# Epoch 1/10
# c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 357s 2s/step - accuracy: 0.0382 - loss: 3.1899
# Epoch 2/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 338s 2s/step - accuracy: 0.1293 - loss: 2.8522
# Epoch 3/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 360s 2s/step - accuracy: 0.2792 - loss: 2.3461
# Epoch 4/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 352s 2s/step - accuracy: 0.6080 - loss: 1.5002
# Epoch 5/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.8809 - loss: 0.6884
# Epoch 6/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 356s 2s/step - accuracy: 0.9827 - loss: 0.2047
# Epoch 7/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 348s 2s/step - accuracy: 1.0000 - loss: 0.0694
# Epoch 8/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 341s 2s/step - accuracy: 0.9937 - loss: 0.0593
# Epoch 9/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 340s 2s/step - accuracy: 1.0000 - loss: 0.0245
# Epoch 10/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 338s 2s/step - accuracy: 1.0000 - loss: 0.0210

# %%
# Evaluate model
test_loss, test_acc = model.evaluate(val_generator)
print(f"Test accuracy: {test_acc}")

# Save model
model.save('workout_classifier_model.h5')
# Out:
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 39s 248ms/step - accuracy: 1.0000 - loss: 0.0082
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test accuracy: 1.0

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load the model
model = load_model('workout_classifier_model.h5')

# Preprocess the video
def preprocess_video(video_path, img_size=(112, 112), max_frames=30):
    cap = cv2.VideoCapture(video_path)
    frames = []
    frame_count = 0

    while cap.isOpened() and frame_count < max_frames:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.resize(frame, img_size)
        frames.append(frame)
        frame_count += 1

    cap.release()

    # If less frames, pad with zeros
    while len(frames) < max_frames:
        frames.append(np.zeros((img_size[0], img_size[1], 3), dtype=np.uint8))

    X = np.array(frames, dtype=np.float32)
    X = X / 255.0  # Normalize pixel values
    X = np.expand_dims(X, axis=0)  # Add batch dimension
    return X

# Predict the video
def predict_video(model, video_path, labels, img_size=(112, 112), max_frames=30):
    X = preprocess_video(video_path, img_size, max_frames)
    predictions = model.predict(X)
    predicted_class = np.argmax(predictions, axis=1)
    predicted_label = labels[predicted_class[0]]
    return predicted_label

# Get the labels
data_path = 'FINAL'
labels = os.listdir(data_path)
labels.sort()  # Ensure the list is sorted to match the order of class indices
print(f'Labels: {labels}')

# Example usage
video_path = 'FINAL\\deadlift\\deadlift_7_edges_h264.mp4'
predicted_label = predict_video(model, video_path, labels)
print(f'The predicted label for the video is: {predicted_label}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Labels: ['barbell biceps curl', 'bench press', 'chest fly machine', 'deadlift', 'decline bench press', 'hammer curl', 'hip thrust', 'incline bench press', 'lat pulldown', 'lateral raise', 'leg extension', 'leg raises', 'plank', 'pull Up', 'push-up', 'romanian deadlift', 'russian twist', 'shoulder press', 'squat', 't bar row', 'tricep Pushdown', 'tricep dips']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# The predicted label for the video is: deadlift
